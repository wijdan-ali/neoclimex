# %%
import pandas as pd
import numpy as np
from pycaret.regression import *

# %%
# Load clean data file
data = pd.read_csv("data_files/clean_data.csv")

# %% [markdown]
# <h4>Note For Feature Engineering:</h4>
# <ul>
#     <li>We will teach the model equilibrium temperature formula's relationship (without stellar radius)</li>
#     <li>The value of albedo varies from planet to planet and isn't available, but in this case we will use an average value of 0.3</li>
# </ul>

# %%
# Feature Engineering 

T_star = data["st_teff"].values
a_planet = data["pl_orbsmax"].values

Feat1 = T_star.copy()
Feat2 = T_star * (np.sqrt(1 / (2*(a_planet)))) * ((1 - 0.3) ** 0.25)
Feat3 = np.log10(T_star)
Feat4 = np.log10(1 / (2*a_planet))
Feat5 = np.log10(T_star * np.sqrt(1 / (2*a_planet)) * ((1 - 0.3) ** 0.25))

# %%
training_df = pd.DataFrame({
    "feat1": Feat1,
    "feat2": Feat2,
    "feat3": Feat3,
    "feat4": Feat4,
    "feat5": Feat5,
    "Eqt": data["pl_eqt"]
})

initial_model = setup(training_df, target = 'Eqt')
# Out:
# <style type="text/css">
# #T_1dde7_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1dde7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1dde7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1dde7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dde7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1dde7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1dde7_row0_col1" class="data row0 col1" >7873</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1dde7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1dde7_row1_col1" class="data row1 col1" >Eqt</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1dde7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1dde7_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1dde7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1dde7_row3_col1" class="data row3 col1" >(11715, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1dde7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1dde7_row4_col1" class="data row4 col1" >(11715, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1dde7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1dde7_row5_col1" class="data row5 col1" >(8200, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1dde7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1dde7_row6_col1" class="data row6 col1" >(3515, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1dde7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_1dde7_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1dde7_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_1dde7_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1dde7_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_1dde7_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1dde7_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_1dde7_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1dde7_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_1dde7_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1dde7_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_1dde7_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1dde7_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_1dde7_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1dde7_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_1dde7_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1dde7_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_1dde7_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1dde7_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_1dde7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1dde7_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_1dde7_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1dde7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1dde7_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_1dde7_row18_col1" class="data row18 col1" >51e4</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_4a55c th {
#   text-align: left;
# }
# #T_4a55c_row0_col0, #T_4a55c_row1_col0, #T_4a55c_row1_col1, #T_4a55c_row1_col2, #T_4a55c_row1_col3, #T_4a55c_row1_col4, #T_4a55c_row1_col5, #T_4a55c_row1_col6, #T_4a55c_row2_col0, #T_4a55c_row2_col1, #T_4a55c_row2_col2, #T_4a55c_row2_col3, #T_4a55c_row2_col4, #T_4a55c_row2_col5, #T_4a55c_row2_col6, #T_4a55c_row3_col0, #T_4a55c_row3_col1, #T_4a55c_row3_col2, #T_4a55c_row3_col3, #T_4a55c_row3_col4, #T_4a55c_row3_col5, #T_4a55c_row3_col6, #T_4a55c_row4_col0, #T_4a55c_row4_col1, #T_4a55c_row4_col2, #T_4a55c_row4_col3, #T_4a55c_row4_col4, #T_4a55c_row4_col5, #T_4a55c_row4_col6, #T_4a55c_row5_col0, #T_4a55c_row5_col1, #T_4a55c_row5_col2, #T_4a55c_row5_col3, #T_4a55c_row5_col4, #T_4a55c_row5_col5, #T_4a55c_row5_col6, #T_4a55c_row6_col0, #T_4a55c_row6_col1, #T_4a55c_row6_col2, #T_4a55c_row6_col3, #T_4a55c_row6_col4, #T_4a55c_row6_col5, #T_4a55c_row6_col6, #T_4a55c_row7_col0, #T_4a55c_row7_col1, #T_4a55c_row7_col2, #T_4a55c_row7_col3, #T_4a55c_row7_col4, #T_4a55c_row7_col5, #T_4a55c_row7_col6, #T_4a55c_row8_col0, #T_4a55c_row8_col1, #T_4a55c_row8_col2, #T_4a55c_row8_col3, #T_4a55c_row8_col4, #T_4a55c_row8_col5, #T_4a55c_row8_col6, #T_4a55c_row9_col0, #T_4a55c_row9_col1, #T_4a55c_row9_col2, #T_4a55c_row9_col3, #T_4a55c_row9_col4, #T_4a55c_row9_col5, #T_4a55c_row9_col6, #T_4a55c_row10_col0, #T_4a55c_row10_col1, #T_4a55c_row10_col2, #T_4a55c_row10_col3, #T_4a55c_row10_col4, #T_4a55c_row10_col5, #T_4a55c_row10_col6, #T_4a55c_row11_col0, #T_4a55c_row11_col1, #T_4a55c_row11_col2, #T_4a55c_row11_col3, #T_4a55c_row11_col4, #T_4a55c_row11_col5, #T_4a55c_row11_col6, #T_4a55c_row12_col0, #T_4a55c_row12_col1, #T_4a55c_row12_col2, #T_4a55c_row12_col3, #T_4a55c_row12_col4, #T_4a55c_row12_col5, #T_4a55c_row12_col6, #T_4a55c_row13_col0, #T_4a55c_row13_col1, #T_4a55c_row13_col2, #T_4a55c_row13_col3, #T_4a55c_row13_col4, #T_4a55c_row13_col5, #T_4a55c_row13_col6, #T_4a55c_row14_col0, #T_4a55c_row14_col1, #T_4a55c_row14_col2, #T_4a55c_row14_col3, #T_4a55c_row14_col4, #T_4a55c_row14_col5, #T_4a55c_row14_col6, #T_4a55c_row15_col0, #T_4a55c_row15_col1, #T_4a55c_row15_col2, #T_4a55c_row15_col3, #T_4a55c_row15_col4, #T_4a55c_row15_col5, #T_4a55c_row15_col6, #T_4a55c_row16_col0, #T_4a55c_row16_col1, #T_4a55c_row16_col2, #T_4a55c_row16_col3, #T_4a55c_row16_col4, #T_4a55c_row16_col5, #T_4a55c_row16_col6, #T_4a55c_row17_col0, #T_4a55c_row17_col1, #T_4a55c_row17_col2, #T_4a55c_row17_col3, #T_4a55c_row17_col4, #T_4a55c_row17_col5, #T_4a55c_row17_col6 {
#   text-align: left;
# }
# #T_4a55c_row0_col1, #T_4a55c_row0_col2, #T_4a55c_row0_col3, #T_4a55c_row0_col4, #T_4a55c_row0_col5, #T_4a55c_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4a55c_row0_col7, #T_4a55c_row1_col7, #T_4a55c_row2_col7, #T_4a55c_row3_col7, #T_4a55c_row4_col7, #T_4a55c_row5_col7, #T_4a55c_row6_col7, #T_4a55c_row9_col7, #T_4a55c_row11_col7, #T_4a55c_row13_col7, #T_4a55c_row15_col7, #T_4a55c_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4a55c_row7_col7, #T_4a55c_row8_col7, #T_4a55c_row10_col7, #T_4a55c_row12_col7, #T_4a55c_row14_col7, #T_4a55c_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4a55c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a55c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4a55c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4a55c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4a55c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4a55c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4a55c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4a55c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4a55c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a55c_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_4a55c_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_4a55c_row0_col1" class="data row0 col1" >37.8114</td>
#       <td id="T_4a55c_row0_col2" class="data row0 col2" >9889.2624</td>
#       <td id="T_4a55c_row0_col3" class="data row0 col3" >98.8164</td>
#       <td id="T_4a55c_row0_col4" class="data row0 col4" >0.8917</td>
#       <td id="T_4a55c_row0_col5" class="data row0 col5" >0.1034</td>
#       <td id="T_4a55c_row0_col6" class="data row0 col6" >0.0454</td>
#       <td id="T_4a55c_row0_col7" class="data row0 col7" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_4a55c_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_4a55c_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_4a55c_row1_col1" class="data row1 col1" >46.0750</td>
#       <td id="T_4a55c_row1_col2" class="data row1 col2" >10373.9496</td>
#       <td id="T_4a55c_row1_col3" class="data row1 col3" >101.2788</td>
#       <td id="T_4a55c_row1_col4" class="data row1 col4" >0.8864</td>
#       <td id="T_4a55c_row1_col5" class="data row1 col5" >0.1062</td>
#       <td id="T_4a55c_row1_col6" class="data row1 col6" >0.0562</td>
#       <td id="T_4a55c_row1_col7" class="data row1 col7" >0.2140</td>
#     </tr>
#     <tr>
#       <th id="T_4a55c_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_4a55c_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4a55c_row2_col1" class="data row2 col1" >65.8864</td>
#       <td id="T_4a55c_row2_col2" class="data row2 col2" >13215.9397</td>
#       <td id="T_4a55c_row2_col3" class="data row2 col3" >114.5969</td>
#       <td id="T_4a55c_row2_col4" class="data row2 col4" >0.8554</td>
#       <td id="T_4a55c_row2_col5" class="data row2 col5" >0.1263</td>
#       <td id="T_4a55c_row2_col6" class="data row2 col6" >0.0848</td>
#       <td id="T_4a55c_row2_col7" class="data row2 col7" >0.2470</td>
#     </tr>
#     <tr>
#       <th id="T_4a55c_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_4a55c_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_4a55c_row3_col1" class="data row3 col1" >67.8607</td>
#       <td id="T_4a55c_row3_col2" class="data row3 col2" >13759.6743</td>
#       <td id="T_4a55c_row3_col3" class="data row3 col3" >116.8371</td>
#       <td id="T_4a55c_row3_col4" class="data row3 col4" >0.8493</td>
#       <td id="T_4a55c_row3_col5" class="data row3 col5" >0.1317</td>
#       <td id="T_4a55c_row3_col6" class="data row3 col6" >0.0862</td>
#       <td id="T_4a55c_row3_col7" class="data row3 col7" >0.0950</td>
#     </tr>
#     <tr>
#       <th id="T_4a55c_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_4a55c_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_4a55c_row4_col1" class="data row4 col1" >65.0935</td>
#       <td id="T_4a55c_row4_col2" class="data row4 col2" >14750.5346</td>
#       <td id="T_4a55c_row4_col3" class="data row4 col3" >121.1259</td>
#       <td id="T_4a55c_row4_col4" class="data row4 col4" >0.8383</td>
#       <td id="T_4a55c_row4_col5" class="data row4 col5" >0.1311</td>
#       <td id="T_4a55c_row4_col6" class="data row4 col6" >0.0821</td>
#       <td id="T_4a55c_row4_col7" class="data row4 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_4a55c_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_4a55c_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_4a55c_row5_col1" class="data row5 col1" >45.8171</td>
#       <td id="T_4a55c_row5_col2" class="data row5 col2" >14852.1126</td>
#       <td id="T_4a55c_row5_col3" class="data row5 col3" >121.3326</td>
#       <td id="T_4a55c_row5_col4" class="data row5 col4" >0.8371</td>
#       <td id="T_4a55c_row5_col5" class="data row5 col5" >0.1272</td>
#       <td id="T_4a55c_row5_col6" class="data row5 col6" >0.0556</td>
#       <td id="T_4a55c_row5_col7" class="data row5 col7" >0.0060</td>
#     </

# %%
tuned_model = tune_model(best_model)

# %%
finalize_model(best_model)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['feat1', 'feat2', 'feat3', 'feat4',
#                                              'feat5'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('actual_estimator',
#                  ExtraTreesRegressor(n_jobs=-1, random_state=7873))])

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
save_model(best_model, "main_model")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['feat1', 'feat2', 'feat3', 'feat4',
#                                               'feat5'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=7873))]),
#  'main_model.pkl')
